# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
import os

notebook_path = os.path.abspath('')
import sys
# Find the part of the path that contains 'commitFit'
commit_fit_path = None
for part in notebook_path.split(os.sep):
    print(part)
    if 'ensemble_commit' in part:
        commit_fit_path = notebook_path.split(part)[0] + part
        print(commit_fit_path)
        break
 
if commit_fit_path is None:
    raise ValueError("Path containing 'ensemble_commit' not found in notebook path.")


if commit_fit_path not in sys.path:
    sys.path.append(commit_fit_path)

import ensemble_model.preprocesser as preprocesser 
import ensemble_model.MoE_model_CE_loss as moe 
from torch.utils.data import Dataset, DataLoader
from transformers import BertModel, BertTokenizer, RobertaModel, RobertaTokenizer, DistilBertModel

# import whatthepatch
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, precision_recall_curve,classification_report
# Out:
# root
# ensemble_commit
# /root/ensemble_commit

# %%
moe.BiLSTMStudent
# Out:
# ensemble_model.MoE_model_CE_loss.BiLSTMStudent

# %%
df = pd.read_csv(r'../datasets/dataset.csv', encoding='utf_8_sig')
df.dropna(inplace=True)
label2id={'negative':0,'positive':1}
df = df.replace({"label": label2id})
df
# Out:
# /tmp/ipykernel_1231/1052552286.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({"label": label2id})
#        Unnamed: 0  label                                            message  \
# 0               0      0  Merge pull request #46 from rufferson/saslx-tl...
# 1               1      1  Fix leaks in kadmin server stubs [CVE-2015-863...
# 2               2      1  Validate authorization request on approval\n\n...
# 3               3      1                              Release 2.72.4+171110
# 4               4      0                          Fixing compiler warnings.
# ...           ...    ...                                                ...
# 10107       10107      0  les: remove useless protocol defines (#22115)\...
# 10108       10108      1  Merge pull request #2067 from realm/tg-swift-l...
# 10109       10109      0                           [fix] 新規アカウント作成ページの翻訳を修正
# 10110       10110      0                            Merge branch 'hotfixes'
# 10111       10111      1  HTTPCLIENT-1803: Improved handling of malforme...
#
#                                                     diff
# 0      diff --git a/lib/DJabberd.pm b/lib/DJabberd.pm...
# 1      diff --git a/src/kadmin/server/server_stubs.c ...
# 2      diff --git a/spring-security-oauth2/src/main/j...
# 3      diff --git a/application/config/version.php b/...
# 4      diff --git a/src/main.c b/src/main.c\nindex 50...
# ...                                                  ...
# 10107  diff --git a/les/benchmark.go b/les/benchmark....
# 10108  diff --git a/CHANGELOG.md b/CHANGELOG.md\ninde...
# 10109  diff --git a/app/locales/ja_JP/LC_MESSAGES/mes...
# 10110  diff --git a/CHANGELOG.txt b/CHANGELOG.txt\nin...
# 10111  diff --git a/httpclient/src/main/java/org/apac...
#
# [10064 rows x 4 columns]

# %%
# df['command'] = df['diff'].apply(lambda x : extract_lines(find_longest_list([y.changes for y in whatthepatch.parse_patch(x)])))
# extracted_cols = df['diff'].str.extract(r'^diff --git (?P<source>[^\t\n]+) (?P<target>[^\t\n]+)')
# whatthepatch.apply_diff(diff, lao)

# %%
# len(df_dataset)

# %%
# df_dataset[0]

# %%
# Load BERT and CodeBERT models and tokenizers
bert_model = BertModel.from_pretrained('../models/bert-base-cased')
bert_tokenizer = BertTokenizer.from_pretrained('../models/bert-base-cased')

codebert_model = BertModel.from_pretrained('../models/bert-base-cased')
codebert_tokenizer = BertTokenizer.from_pretrained('../models/bert-base-cased')
# Out:
# Some weights of the model checkpoint at ../models/bert-base-cased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at ../models/bert-base-cased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
train_data, _ = train_test_split(df, train_size=0.35, random_state=42)
train_data, test_data = train_test_split(train_data, test_size=0.3, random_state=42)
# train_data = pd.read_csv('./datasets/PD_train.csv')
# test_data = pd.read_csv('./datasets/PD_test.csv')
# val_data = pd.read_csv('./datasets/PD_val.csv')

# %%
len(train_data)
# Out:
# 2465

# %%
# codebert_model.config.hidden_size

# %%
len(test_data)
# Out:
# 1057

# %%
test_data, val_data = train_test_split(test_data, train_size=0.5, random_state=42)

# %%
train_data.reset_index(inplace=True)
test_data.reset_index(inplace=True)
val_data.reset_index(inplace=True)

# %%
train_data['label'].value_counts()
# Out:
# label
# 0    1512
# 1     953
# Name: count, dtype: int64

# %%
val_data
# Out:
#      index  Unnamed: 0  label  \
# 0     5106        5106      0
# 1     3322        3322      0
# 2     3187        3187      1
# 3     8592        8592      0
# 4     7272        7272      0
# ..     ...         ...    ...
# 524   1500        1500      0
# 525   1141        1141      0
# 526   2921        2921      1
# 527   8292        8292      0
# 528   2989        2989      1
#
#                                                message  \
# 0    Merge pull request #6 from daniel-beck-bot/htt...
# 1                                     Fix Gitter badge
# 2          Check for presence of crsf in admin scripts
# 3                                    Fixed link errors
# 4    Fixed memory corruption introduced when creati...
# ..                                                 ...
# 524                                                ...
# 525                            SONY: added ImageCount3
# 526  Fix bug #68942 (Use after free vulnerability i...
# 527                   先把 zbpimage 和 thumb 改成 thumbnail
# 528  Ensure request and response facades are used w...
#
#                                                   diff
# 0    diff --git a/pom.xml b/pom.xml\nindex 661ce51....
# 1    diff --git a/README.md b/README.md\nindex eff9...
# 2    diff --git a/src/Lua.cpp b/src/Lua.cpp\nindex ...
# 3    diff --git a/src/irisnet/CMakeLists.txt b/src/...
# 4    diff --git a/Doxyfile b/Doxyfile\nindex f88538...
# ..                                                 ...
# 524  diff --git a/config/policy.xml b/config/policy...
# 525  diff --git a/dcraw/dcraw.c b/dcraw/dcraw.c\nin...
# 526  diff --git a/NEWS b/NEWS\nindex 0d93c47b02007....
# 527  diff --git a/zb_system/function/c_system_event...
# 528  diff --git a/java/org/apache/catalina/authenti...
#
# [529 rows x 5 columns]

# %%
val_data
# Out:
#      index  Unnamed: 0  label  \
# 0     5106        5106      0
# 1     3322        3322      0
# 2     3187        3187      1
# 3     8592        8592      0
# 4     7272        7272      0
# ..     ...         ...    ...
# 524   1500        1500      0
# 525   1141        1141      0
# 526   2921        2921      1
# 527   8292        8292      0
# 528   2989        2989      1
#
#                                                message  \
# 0    Merge pull request #6 from daniel-beck-bot/htt...
# 1                                     Fix Gitter badge
# 2          Check for presence of crsf in admin scripts
# 3                                    Fixed link errors
# 4    Fixed memory corruption introduced when creati...
# ..                                                 ...
# 524                                                ...
# 525                            SONY: added ImageCount3
# 526  Fix bug #68942 (Use after free vulnerability i...
# 527                   先把 zbpimage 和 thumb 改成 thumbnail
# 528  Ensure request and response facades are used w...
#
#                                                   diff
# 0    diff --git a/pom.xml b/pom.xml\nindex 661ce51....
# 1    diff --git a/README.md b/README.md\nindex eff9...
# 2    diff --git a/src/Lua.cpp b/src/Lua.cpp\nindex ...
# 3    diff --git a/src/irisnet/CMakeLists.txt b/src/...
# 4    diff --git a/Doxyfile b/Doxyfile\nindex f88538...
# ..                                                 ...
# 524  diff --git a/config/policy.xml b/config/policy...
# 525  diff --git a/dcraw/dcraw.c b/dcraw/dcraw.c\nin...
# 526  diff --git a/NEWS b/NEWS\nindex 0d93c47b02007....
# 527  diff --git a/zb_system/function/c_system_event...
# 528  diff --git a/java/org/apache/catalina/authenti...
#
# [529 rows x 5 columns]

# %%
# Create Datasets and DataLoaders
train_dataset = preprocesser.SentencePairDataset(train_data, bert_tokenizer, codebert_tokenizer, message='message',command='diff',label='label')
val_dataset = preprocesser.SentencePairDataset(val_data, bert_tokenizer, codebert_tokenizer, message='message',command='diff',label='label')
test_dataset = preprocesser.SentencePairDataset(test_data, bert_tokenizer, codebert_tokenizer, message='message',command='diff',label='label')

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)



# # Initialize the model
# model = em.CombinedModel(bert_model, codebert_model, bert_tokenizer, codebert_tokenizer)

# # Train the model
# model.trainer(train_loader, val_loader,num_epochs=10)
# for batch in train_loader:
#     print(batch)

# %%
base_model1 = moe.BaseModel(bert_model)
base_model2 = moe.BaseModel(codebert_model)

# %%
# Load BERT and CodeBERT models and tokenizers
bert_model = DistilBertModel.from_pretrained('/root/autodl-tmp/IPCK/model/distilbert')

codebert_model = DistilBertModel.from_pretrained('/root/autodl-tmp/IPCK/model/distilbert')
# Out:
# Some weights of the model checkpoint at /root/autodl-tmp/IPCK/model/distilbert were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at /root/autodl-tmp/IPCK/model/distilbert were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
encoder_model1 = moe.EncoderModel(bert_model)
encoder_model2 = moe.EncoderModel(bert_model)

# %%
# Create stacking model
moe_model = moe.MoEModel(base_model1, base_model2)
# Train the model
moe_model.trainer(train_loader, val_loader,num_epochs=10, patience=3)
# Out:
# /root/miniconda3/lib/python3.10/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1/10 Loss: 0.6307: 100%|██████████| 309/309 [05:36<00:00,  1.09s/batch]
# =============================train========================
# Validation Accuracy: 0.5898
# Precision: 0.3479
# Recall: 0.5898
# F1-Score: 0.4376
# /root/miniconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/miniconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/miniconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0     0.5898    1.0000    0.7420       312
#            1     0.0000    0.0000    0.0000       217
#
#     accuracy                         0.5898       529
#    macro avg     0.2949    0.5000    0.3710       529
# weighted avg     0.3479    0.5898    0.4376       529
# Epoch 2/10 Loss: 0.4410: 100%|██████████| 309/309 [05:35<00:00,  1.08s/batch]
# =============================train========================
# Validation Accuracy: 0.7769
# Precision: 0.8060
# Recall: 0.7769
# F1-Score: 0.7607
#               precision    recall  f1-score   support
#
#            0     0.7389    0.9615    0.8357       312
#            1     0.9024    0.5115    0.6529       217
#
#     accuracy                         0.7769       529
#    macro avg     0.8207    0.7365    0.7443       529
# weighted avg     0.8060    0.7769    0.7607       529
# Epoch 3/10 Loss: 0.2415: 100%|██████████| 309/309 [05:28<00:00,  1.06s/batch]
# =============================train========================
# Validation Accuracy: 0.8393
# Precision: 0.8388
# Recall: 0.8393
# F1-Score: 0.8382
#               precision    recall  f1-score   support
#
#            0     0.8450    0.8910    0.8674       312
#            1     0.8300    0.7650    0.7962       217
#
#     accuracy                         0.8393       529
#    macro avg     0.8375    0.8280    0.8318       529
# weighted avg     0.8388    0.8393    0.8382       529
# Epoch 4/10 Loss: 0.1222: 100%|██████████| 309/309 [05:36<00:00,  1.09s/batch]
# =============================train========================
# Validation Accuracy: 0.7921
# Precision: 0.8131
# Recall: 0.7921
# F1-Score: 0.7937
#               precision    recall  f1-score   support
#
#            0     0.8945    0.7340    0.8063       312
#            1     0.6960    0.8756    0.7755       217
#
#     accuracy                         0.7921       529
#    macro avg     0.7953    0.8048    0.7909       529
# weighted avg     0.8131    0.7921    0.7937       529
# Epoch 5/10 Loss: 0.0758: 100%|██████████| 309/309 [05:31<00:00,  1.07s/batch]
# =============================train========================
# Validation Accuracy: 0.8318
# Precision: 0.8319
# Recall: 0.8318
# F1-Score: 0.8318
#               precision    recall  f1-score   support
#
#            0     0.8585    0.8558    0.8571       312
#            1     0.7936    0.7972    0.7954       217
#
#     accuracy                         0.8318       529
#    macro avg     0.8260    0.8265    0.8263       529
# weighted avg     0.8319    0.8318    0.8318       529
# Epoch 6/10 Loss: 0.0570: 100%|██████████| 309/309 [05:35<00:00,  1.09s/batch]
# =============================train========================
# Validation Accuracy: 0.8261
# Precision: 0.8339
# Recall: 0.8261
# F1-Score: 0.8273
#               precision    recall  f1-score   support
#
#            0     0.8901    0.8045    0.8451       312
#            1     0.7530    0.8571    0.8017       217
#
#     accuracy                         0.8261       529
#    macro avg     0.8216    0.8308    0.8234       529
# weighted avg     0.8339    0.8261    0.8273       529
# Epoch 7/10 Loss: 0.0448: 100%|██████████| 309/309 [05:44<00:00,  1.11s/batch]
# =============================train========================
# Validation Accuracy: 0.8242
# Precision: 0.8316
# Recall: 0.8242
# F1-Score: 0.8254
#               precision    recall  f1-score   support
#
#            0     0.8869    0.8045    0.8437       312
#            1     0.7520    0.8525    0.7991       217
#
#     accuracy                         0.8242       529
#    macro avg     0.8195    0.8285    0.8214       529
# weighted avg     0.8316    0.8242    0.8254       529
# Epoch 8/10 Loss: 0.0375: 100%|██████████| 309/309 [05:34<00:00,  1.08s/batch]
# =============================train========================
# Validation Accuracy: 0.8129
# Precision: 0.8310
# Recall: 0.8129
# F1-Score: 0.8144
#               precision    recall  f1-score   support
#
#            0     0.9080    0.7596    0.8272       312
#            1     0.7201    0.8894    0.7959       217
#
#     accuracy                         0.8129       529
#    macro avg     0.8141    0.8245    0.8116       529
# weighted avg     0.8310    0.8129    0.8144       529
# Epoch 9/10 Loss: 0.0324: 100%|██████████| 309/309 [05:29<00:00,  1.07s/batch]
# =============================train========================
# Validation Accuracy: 0.8242
# Precision: 0.8379
# Recall: 0.8242
# F1-Score: 0.8256
#               precision    recall  f1-score   support
#
#            0     0.9071    0.7821    0.8399       312
#            1     0.7385    0.8848    0.8050       217
#
#     accuracy                         0.8242       529
#    macro avg     0.8228    0.8334    0.8225       529
# weighted avg     0.8379    0.8242    0.8256       529
# Epoch 10/10 Loss: 0.0370: 100%|██████████| 309/309 [05:32<00:00,  1.07s/batch]
# =============================train========================
# Validation Accuracy: 0.8469
# Precision: 0.8464
# Recall: 0.8469
# F1-Score: 0.8459
#               precision    recall  f1-score   support
#
#            0     0.8532    0.8942    0.8732       312
#            1     0.8366    0.7788    0.8067       217
#
#     accuracy                         0.8469       529
#    macro avg     0.8449    0.8365    0.8400       529
# weighted avg     0.8464    0.8469    0.8459       529

# %%
test_dataset = preprocesser.SentencePairDataset(test_data, bert_tokenizer, codebert_tokenizer,message='message',command='diff',label='label')
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# %%
torch.save(moe_model, "CE_entire_bert_model_900repo-1-12.pth")

# %%
# moe_model = torch.load("entire_bert_model_900repo.pth")

# %%
test_acc, test_labels, test_probabilities, test_embeddings, test_predictions = moe_model.evaluate(test_loader)
# Out:
# Validation Accuracy: 0.8693
# Precision: 0.8690
# Recall: 0.8693
# F1-Score: 0.8673
#               precision    recall  f1-score   support
#
#            0     0.8715    0.9313    0.9004       335
#            1     0.8647    0.7617    0.8099       193
#
#     accuracy                         0.8693       528
#    macro avg     0.8681    0.8465    0.8552       528
# weighted avg     0.8690    0.8693    0.8673       528

# %%
print(classification_report(test_labels,test_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       335
#            1       0.86      0.76      0.81       193
#
#     accuracy                           0.87       528
#    macro avg       0.87      0.85      0.86       528
# weighted avg       0.87      0.87      0.87       528

# %%
test_acc
# Out:
# 0.8693181818181818

# %%
#发送多种类型的邮件
from email.mime.multipart import MIMEMultipart
import smtplib

from email.mime.text import MIMEText
msg_from = '915803745@qq.com'  # 发送方邮箱
passwd = 'vcuosuurrgkfbdai'   #就是上面的授权码
 
# to= ['g.zhang@gotion.com', 'j.tong@gotion.com'] #接受方邮箱
to= ['j.tong@gotion.com'] #接受方邮箱
#设置邮件内容
#MIMEMultipart类可以放任何内容
msg = MIMEMultipart()
conntent="在线模型训练完毕"
#把内容加进去
msg.attach(MIMEText(conntent,'plain','utf-8'))
 
#设置邮件主题
msg['Subject']="在线模型训练完毕"
 
#发送方信息
msg['From']=msg_from
 
#开始发送
 
#通过SSL方式发送，服务器地址和端口
s = smtplib.SMTP_SSL("smtp.qq.com", 465)
# 登录邮箱
s.login(msg_from, passwd)
#开始发送
s.sendmail(msg_from,to,msg.as_string())
print("在线模型训练完毕")
# Out:
# 在线模型训练完毕
