# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score

# train_data, test_data = train_test_split(df, test_size=0.3, random_state=42)
# test_data, val_data = train_test_split(test_data, test_size=0.5, random_state=42)
train = pd.read_csv('./datasets/PD_train.csv')
test = pd.read_csv('./datasets/PD_test.csv')
val = pd.read_csv('./datasets/PD_val.csv')

train.reset_index(inplace=True)
test.reset_index(inplace=True)
val.reset_index(inplace=True)
# 1. 数据预处理和特征提取

vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(train['commit_message'])
y_train = train['category']

# 3. 训练决策树分类器
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# 4. 评估模型
y_pred = clf.predict(vectorizer.transform(test['commit_message']))
print("Accuracy:", accuracy_score(test['category'], y_pred))
print("Classification Report:\n", classification_report(test['category'], y_pred, digits=4))
# Out:
# Accuracy: 0.8776991809381981
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9103    0.9033    0.9068      3537
#            1     0.8163    0.8283    0.8223      1835
#
#     accuracy                         0.8777      5372
#    macro avg     0.8633    0.8658    0.8645      5372
# weighted avg     0.8782    0.8777    0.8779      5372

# %%
val
# Out:
#       index  Unnamed: 0 CVE_ID CWE_ID  category  \
# 0         0       31104    NaN    NaN         1
# 1         1        3833    NaN    NaN         0
# 2         2       19412    NaN    NaN         0
# 3         3       11178    NaN    NaN         0
# 4         4       13781    NaN    NaN         0
# ...     ...         ...    ...    ...       ...
# 5368   5368       21989    NaN    NaN         0
# 5369   5369       11040    NaN    NaN         0
# 5370   5370        4840    NaN    NaN         0
# 5371   5371       15822    NaN    NaN         0
# 5372   5372        2300    NaN    NaN         0
#
#                                      commit_id  \
# 0     31e91e0f40547816f9256d5865d39d504706ad06
# 1     dfea00191aec19dc1115934a3c06e97fd8338e2e
# 2     21a36f4840b1f816364ca91e693619ae03266f08
# 3     7547881d0951384f9833ec3a80fac8f3f16f3b98
# 4     24adaf7958847e0950b197ac05cced2ea9e0b4e7
# ...                                        ...
# 5368  c4c373bab376f7d4accb8af8eb3dfc41a99ae2d4
# 5369  8b7d2a4dc4dd285fdfb7a8e4f71c401c5e0a6566
# 5370  d3d9acf646679c1981032b0985b386d12fccc60c
# 5371  8379e4823d04e2552e1395c2410fc16733e28c6e
# 5372  924b6231edfaf1e764ffb4f97ea382bf4facff58
#
#                                          commit_message  \
# 0     commit 31e91e0f40547816f9256d5865d39d504706ad0...
# 1     commit dfea00191aec19dc1115934a3c06e97fd8338e2...
# 2     commit 21a36f4840b1f816364ca91e693619ae03266f0...
# 3     commit 7547881d0951384f9833ec3a80fac8f3f16f3b9...
# 4     commit 24adaf7958847e0950b197ac05cced2ea9e0b4e...
# ...                                                 ...
# 5368  commit c4c373bab376f7d4accb8af8eb3dfc41a99ae2d...
# 5369  commit 8b7d2a4dc4dd285fdfb7a8e4f71c401c5e0a656...
# 5370  commit d3d9acf646679c1981032b0985b386d12fccc60...
# 5371  commit 8379e4823d04e2552e1395c2410fc16733e28c6...
# 5372  commit 924b6231edfaf1e764ffb4f97ea382bf4facff5...
#
#                                               diff_code        owner  \
# 0     diff --git a/drivers/staging/most/aim-sound/so...   stoth68000
# 1     diff --git a/drivers/media/video/mt9p031.c b/d...        mjg59
# 2     diff --git a/cgminer.c b/cgminer.c\nindex 6e47...  sgminer-dev
# 3     diff --git a/drivers/block/nvme.c b/drivers/bl...   stoth68000
# 4     diff --git a/drivers/iio/adc/ti_am335x_adc.c b...        mjg59
# ...                                                 ...          ...
# 5368  diff --git a/src/sbatch/sbatch.c b/src/sbatch/...      SchedMD
# 5369  diff --git a/lib/asn1/der_get.c b/lib/asn1/der...      heimdal
# 5370  diff --git a/kernel/trace/trace_events_filter....        mjg59
# 5371  diff --git a/drivers/gpu/drm/exynos/exynos_mix...        mjg59
# 5372  diff --git a/drivers/pci/intel-iommu.c b/drive...        mjg59
#
#             repo source
# 0     media-tree   wild
# 1          linux   wild
# 2        sgminer   wild
# 3     media-tree   wild
# 4          linux   wild
# ...          ...    ...
# 5368       slurm   wild
# 5369     heimdal   wild
# 5370       linux   wild
# 5371       linux   wild
# 5372       linux   wild
#
# [5373 rows x 11 columns]

# %%
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(train['diff_code'])
y_train = train['category']

# 3. 训练决策树分类器
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# 4. 评估模型
y_pred = clf.predict(vectorizer.transform(test['diff_code']))
print("Accuracy:", accuracy_score(test['category'], y_pred))
print("Classification Report:\n", classification_report(test['category'], y_pred, digits=4))
